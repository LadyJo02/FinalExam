# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

import os
import sqlalchemy
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## **Data Extraction**

# %%
# Connect to staging area (CRM)
staging_CRM_URL = os.getenv("STAGING_CRM_URL")
engine_crm = sqlalchemy.create_engine(staging_CRM_URL, client_encoding='utf8', pool_pre_ping=True)
connection_crm = engine_crm.connect()

# Check database tables (CRM)
CRM_tables = sqlalchemy.inspect(engine_crm)
print(CRM_tables.get_table_names())
# Out:
# ['CRM_cust_info', 'CRM_prd_info', 'CRM_sales_info']

# %%
# Convert to DataFrames (CRM)
CRM_cust_info = pd.read_sql('SELECT * FROM "CRM_cust_info";', con=connection_crm)
CRM_prd_info = pd.read_sql('SELECT * FROM "CRM_prd_info";', con=connection_crm)
CRM_sales_info = pd.read_sql('SELECT * FROM "CRM_sales_info";', con=connection_crm)

# %%
# Close connections and dispose engines
connection_crm.close()
engine_crm.dispose()

# %%
# Connect to staging area (ERP)
staging_ERP_URL = os.getenv("STAGING_ERP_URL")
engine_erp = sqlalchemy.create_engine(staging_ERP_URL,  client_encoding='utf8')
connection_erp = engine_erp.connect()

# Check database tables (ERP)
ERP_tables = sqlalchemy.inspect(engine_erp)
print(ERP_tables.get_table_names())
# Out:
# ['ERP_cust', 'ERP_loc', 'ERP_px']

# %%
# Convert to DataFrames (ERP)
ERP_cust = pd.read_sql('SELECT * FROM "ERP_cust";', con=connection_erp)
ERP_loc = pd.read_sql('SELECT * FROM "ERP_loc";', con=connection_erp)
ERP_px = pd.read_sql('SELECT * FROM "ERP_px";', con=connection_erp)

# %%
# Close connections and dispose engines
connection_erp.close()
engine_erp.dispose()

# %% [markdown]
# ## **Data Transformation**

# %% [markdown]
# ### **For CRM**

# %%
CRM_cust_info.head()
# Out:
#     cst_id     cst_key cst_firstname cst_lastname cst_marital_status cst_gndr  \
# 0  11000.0  AW00011000           Jon        Yang                   M        M
# 1  11001.0  AW00011001        Eugene      Huang                    S        M
# 2  11002.0  AW00011002         Ruben       Torres                  M        M
# 3  11003.0  AW00011003       Christy          Zhu                  S        F
# 4  11004.0  AW00011004     Elizabeth      Johnson                  S        F
#
#   cst_create_date
# 0      2025-10-06
# 1      2025-10-06
# 2      2025-10-06
# 3      2025-10-06
# 4      2025-10-06

# %%
CRM_cust_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18494 entries, 0 to 18493
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cst_id              18490 non-null  float64
#  1   cst_key             18494 non-null  object
#  2   cst_firstname       18486 non-null  object
#  3   cst_lastname        18487 non-null  object
#  4   cst_marital_status  18487 non-null  object
#  5   cst_gndr            13916 non-null  object
#  6   cst_create_date     18490 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1011.5+ KB

# %%
# Replace null values
CRM_cust_info.fillna(0, inplace=True)
CRM_prd_info.fillna(0, inplace=True)
CRM_sales_info.fillna(0, inplace=True)

# Fix data types
CRM_cust_info['cst_id'] = CRM_cust_info['cst_id'].astype(int)
CRM_cust_info['cst_create_date'] = pd.to_datetime(CRM_cust_info['cst_create_date'], format='mixed', errors='coerce')
CRM_cust_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18494 entries, 0 to 18493
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cst_id              18494 non-null  int64
#  1   cst_key             18494 non-null  object
#  2   cst_firstname       18494 non-null  object
#  3   cst_lastname        18494 non-null  object
#  4   cst_marital_status  18494 non-null  object
#  5   cst_gndr            18494 non-null  object
#  6   cst_create_date     18494 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1011.5+ KB

# %%
CRM_prd_info.head()
# Out:
#    prd_id           prd_key                     prd_nm  prd_cost prd_line  \
# 0     210  CO-RF-FR-R92B-58  HL Road Frame - Black- 58       0.0       R
# 1     211  CO-RF-FR-R92R-58    HL Road Frame - Red- 58       0.0       R
# 2     212   AC-HE-HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3     213   AC-HE-HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4     214   AC-HE-HL-U509-R      Sport-100 Helmet- Red      13.0       S
#
#   prd_start_dt  prd_end_dt
# 0   2003-07-01           0
# 1   2003-07-01           0
# 2   2011-07-01  2007-12-28
# 3   2012-07-01  2008-12-27
# 4   2013-07-01           0

# %%
CRM_prd_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   prd_id        397 non-null    int64
#  1   prd_key       397 non-null    object
#  2   prd_nm        397 non-null    object
#  3   prd_cost      397 non-null    float64
#  4   prd_line      397 non-null    object
#  5   prd_start_dt  397 non-null    object
#  6   prd_end_dt    397 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 21.8+ KB

# %%
# Fix data types
CRM_prd_info['prd_start_dt'] = pd.to_datetime(CRM_prd_info['prd_start_dt'], format='mixed', errors='coerce')
CRM_prd_info['prd_end_dt'] = pd.to_datetime(CRM_prd_info['prd_end_dt'], format='mixed', errors='coerce')
CRM_prd_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   prd_id        397 non-null    int64
#  1   prd_key       397 non-null    object
#  2   prd_nm        397 non-null    object
#  3   prd_cost      397 non-null    float64
#  4   prd_line      397 non-null    object
#  5   prd_start_dt  397 non-null    datetime64[ns]
#  6   prd_end_dt    397 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 21.8+ KB

# %%
CRM_sales_info.head()
# Out:
#   sls_ord_num sls_prd_key  sls_cust_id  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0     SO43697  BK-R93R-62        21768      20101229     20110105    20110110
# 1     SO43698  BK-M82S-44        28389      20101229     20110105    20110110
# 2     SO43699  BK-M82S-44        25863      20101229     20110105    20110110
# 3     SO43700  BK-R50B-62        14501      20101229     20110105    20110110
# 4     SO43701  BK-M82S-44        11003      20101229     20110105    20110110
#
#    sls_sales  sls_quantity  sls_price
# 0     3578.0             1     3578.0
# 1     3400.0             1     3400.0
# 2     3400.0             1     3400.0
# 3      699.0             1      699.0
# 4     3400.0             1     3400.0

# %%
CRM_sales_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sls_ord_num   60398 non-null  object
#  1   sls_prd_key   60398 non-null  object
#  2   sls_cust_id   60398 non-null  int64
#  3   sls_order_dt  60398 non-null  int64
#  4   sls_ship_dt   60398 non-null  int64
#  5   sls_due_dt    60398 non-null  int64
#  6   sls_sales     60398 non-null  float64
#  7   sls_quantity  60398 non-null  int64
#  8   sls_price     60398 non-null  float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 4.1+ MB

# %%
# Fix data types
CRM_sales_info['sls_order_dt'] = pd.to_datetime(CRM_sales_info['sls_order_dt'].astype(str), format='%Y%m%d', errors='coerce')
CRM_sales_info['sls_ship_dt'] = pd.to_datetime(CRM_sales_info['sls_ship_dt'].astype(str), format='%Y%m%d', errors='coerce')
CRM_sales_info['sls_due_dt'] = pd.to_datetime(CRM_sales_info['sls_due_dt'].astype(str), format='%Y%m%d', errors='coerce')
CRM_sales_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sls_ord_num   60398 non-null  object
#  1   sls_prd_key   60398 non-null  object
#  2   sls_cust_id   60398 non-null  int64
#  3   sls_order_dt  60379 non-null  datetime64[ns]
#  4   sls_ship_dt   60398 non-null  datetime64[ns]
#  5   sls_due_dt    60398 non-null  datetime64[ns]
#  6   sls_sales     60398 non-null  float64
#  7   sls_quantity  60398 non-null  int64
#  8   sls_price     60398 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(2), object(2)
# memory usage: 4.1+ MB

# %%
# Merge Sales and Customer DataFrames
CRM_sales_cust = CRM_sales_info.merge(CRM_cust_info, how='left', left_on='sls_cust_id', right_on='cst_id')
CRM_sales_cust
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05
# 1         SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05
# 2         SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05
# 3         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# 4         SO43701  BK-M82S-44        11003   2010-12-29  2011-01-05
# ...           ...         ...          ...          ...         ...
# 60402     SO75122     FE-6654        15868   2014-01-28  2014-02-04
# 60403     SO75122     CA-1098        15868   2014-01-28  2014-02-04
# 60404     SO75123     FE-6654        18759   2014-01-28  2014-02-04
# 60405     SO75123     ST-1401        18759   2014-01-28  2014-02-04
# 60406     SO75123     CA-1098        18759   2014-01-28  2014-02-04
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price  cst_id     cst_key  \
# 0     2011-01-10     3578.0             1     3578.0   21768  AW00021768
# 1     2011-01-10     3400.0             1     3400.0   28389  AW00028389
# 2     2011-01-10     3400.0             1     3400.0   25863  AW00025863
# 3     2011-01-10      699.0             1      699.0   14501  AW00014501
# 4     2011-01-10     3400.0             1     3400.0   11003  AW00011003
# ...          ...        ...           ...        ...     ...         ...
# 60402 2014-02-09       22.0             1       22.0   15868  AW00015868
# 60403 2014-02-09        9.0             1        9.0   15868  AW00015868
# 60404 2014-02-09       22.0             1       22.0   18759  AW00018759
# 60405 2014-02-09      159.0             1      159.0   18759  AW00018759
# 60406 2014-02-09        9.0             1        9.0   18759  AW00018759
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S        0      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M        0      2025-10-12
# 4           Christy          Zhu                  S        F      2025-10-06
# ...             ...          ...                ...      ...             ...
# 60402         Caleb          Lal                  S        M      2026-01-04
# 60403         Caleb          Lal                  S        M      2026-01-04
# 60404         Devin     Phillips                  S        M      2026-01-04
# 60405         Devin     Phillips                  S        M      2026-01-04
# 60406         Devin     Phillips                  S        M      2026-01-04
#
# [60407 rows x 16 columns]

# %%
# Fix product key format
CRM_prd_info['prd_key'] = CRM_prd_info['prd_key'].astype(str)
CRM_prd_info['prd_key'] = CRM_prd_info['prd_key'].str.split('-').str[2:]
CRM_prd_info['prd_key'] = CRM_prd_info['prd_key'].apply(lambda x: '-'.join(x))
CRM_prd_info.head()
# Out:
#    prd_id     prd_key                     prd_nm  prd_cost prd_line  \
# 0     210  FR-R92B-58  HL Road Frame - Black- 58       0.0       R
# 1     211  FR-R92R-58    HL Road Frame - Red- 58       0.0       R
# 2     212   HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3     213   HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4     214   HL-U509-R      Sport-100 Helmet- Red      13.0       S
#
#   prd_start_dt prd_end_dt
# 0   2003-07-01 1970-01-01
# 1   2003-07-01 1970-01-01
# 2   2011-07-01 2007-12-28
# 3   2012-07-01 2008-12-27
# 4   2013-07-01 1970-01-01

# %%
# Merge Sales_Customer and Product DataFrames
CRM_sales_cust_prod = CRM_sales_cust.merge(CRM_prd_info, how='left', left_on='sls_prd_key', right_on='prd_key')
CRM_sales_cust_prod
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05
# 1         SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05
# 2         SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05
# 3         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# 4         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# ...           ...         ...          ...          ...         ...
# 89828     SO75123     FE-6654        18759   2014-01-28  2014-02-04
# 89829     SO75123     ST-1401        18759   2014-01-28  2014-02-04
# 89830     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89831     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89832     SO75123     CA-1098        18759   2014-01-28  2014-02-04
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price  cst_id     cst_key  \
# 0     2011-01-10     3578.0             1     3578.0   21768  AW00021768
# 1     2011-01-10     3400.0             1     3400.0   28389  AW00028389
# 2     2011-01-10     3400.0             1     3400.0   25863  AW00025863
# 3     2011-01-10      699.0             1      699.0   14501  AW00014501
# 4     2011-01-10      699.0             1      699.0   14501  AW00014501
# ...          ...        ...           ...        ...     ...         ...
# 89828 2014-02-09       22.0             1       22.0   18759  AW00018759
# 89829 2014-02-09      159.0             1      159.0   18759  AW00018759
# 89830 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89831 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89832 2014-02-09        9.0             1        9.0   18759  AW00018759
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date  \
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S        0      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M        0      2025-10-12
# 4             Ruben       Prasad                  M        0      2025-10-12
# ...             ...          ...                ...      ...             ...
# 89828         Devin     Phillips                  S        M      2026-01-04
# 89829         Devin     Phillips                  S        M      2026-01-04
# 89830         Devin     Phillips                  S        M      2026-01-04
# 89831         Devin     Phillips                  S        M      2026-01-04
# 89832         Devin     Phillips                  S        M      2026-01-04
#
#        prd_id     prd_key                   prd_nm  prd_cost prd_line  \
# 0         310  BK-R93R-62         Road-150 Red- 62    2171.0       R
# 1         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 2         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 3         336  BK-R50B-62       Road-650 Black- 62     413.0       R
# 4         337  BK-R50B-62       Road-650 Black- 62     487.0       R
# ...       ...         ...                      ...       ...      ...
# 89828     485     FE-6654    Fender Set - Mountain       8.0       M
# 89829     486     ST-1401   All-Purpose Bike Stand      59.0       M
# 89830     223     CA-1098             AWC Logo Cap       6.0       S
# 89831     224     CA-1098             AWC Logo Cap       5.0       S
# 89832     225     CA-1098             AWC Logo Cap       7.0       S
#
#       prd_start_dt prd_end_dt
# 0       2011-07-01 2007-12-28
# 1       2011-07-01 2007-12-28
# 2       2011-07-01 2007-12-28
# 3       2011-07-01 2007-12-28
# 4       2012-07-01 2008-12-27
# ...            ...        ...
# 89828   2013-07-01 1970-01-01
# 89829   2013-07-01 1970-01-01
# 89830   2011-07-01 2007-12-28
# 89831   2012-07-01 2008-12-27
# 89832   2013-07-01 1970-01-01
#
# [89833 rows x 23 columns]

# %%
CRM_sales_cust_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89833 entries, 0 to 89832
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sls_ord_num         89833 non-null  object
#  1   sls_prd_key         89833 non-null  object
#  2   sls_cust_id         89833 non-null  int64
#  3   sls_order_dt        89809 non-null  datetime64[ns]
#  4   sls_ship_dt         89833 non-null  datetime64[ns]
#  5   sls_due_dt          89833 non-null  datetime64[ns]
#  6   sls_sales           89833 non-null  float64
#  7   sls_quantity        89833 non-null  int64
#  8   sls_price           89833 non-null  float64
#  9   cst_id              89833 non-null  int64
#  10  cst_key             89833 non-null  object
#  11  cst_firstname       89833 non-null  object
#  12  cst_lastname        89833 non-null  object
#  13  cst_marital_status  89833 non-null  object
#  14  cst_gndr            89833 non-null  object
#  15  cst_create_date     89833 non-null  datetime64[ns]
#  16  prd_id              89833 non-null  int64
#  17  prd_key             89833 non-null  object
#  18  prd_nm              89833 non-null  object
#  19  prd_cost            89833 non-null  float64
#  20  prd_line            89833 non-null  object
#  21  prd_start_dt        89833 non-null  datetime64[ns]
#  22  prd_end_dt          89833 non-null  datetime64[ns]
# dtypes: datetime64[ns](6), float64(3), int64(4), object(10)
# memory usage: 15.8+ MB

# %% [markdown]
# ### **For ERP**

# %%
ERP_cust.head()
# Out:
#              CID       BDATE     GEN
# 0  NASAW00011000  1971-10-06    Male
# 1  NASAW00011001  1976-05-10    Male
# 2  NASAW00011002  1971-02-09    Male
# 3  NASAW00011003  1973-08-14  Female
# 4  NASAW00011004  1979-08-05  Female

# %%
ERP_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CID     18484 non-null  object
#  1   BDATE   18484 non-null  object
#  2   GEN     17012 non-null  object
# dtypes: object(3)
# memory usage: 433.3+ KB

# %%
# Fix data type
ERP_cust['BDATE'] = pd.to_datetime(ERP_cust['BDATE'], format='%Y-%m-%d', errors='coerce')

# %%
ERP_loc.head()
# Out:
#            CID      CNTRY
# 0  AW-00011000  Australia
# 1  AW-00011001  Australia
# 2  AW-00011002  Australia
# 3  AW-00011003  Australia
# 4  AW-00011004  Australia

# %%
ERP_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CID     18484 non-null  object
#  1   CNTRY   18152 non-null  object
# dtypes: object(2)
# memory usage: 288.9+ KB

# %%
ERP_px.head()
# Out:
#       ID          CAT             SUBCAT MAINTENANCE
# 0  AC_BR  Accessories         Bike Racks         Yes
# 1  AC_BS  Accessories        Bike Stands          No
# 2  AC_BC  Accessories  Bottles and Cages          No
# 3  AC_CL  Accessories           Cleaners         Yes
# 4  AC_FE  Accessories            Fenders          No

# %%
ERP_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           37 non-null     object
#  1   CAT          37 non-null     object
#  2   SUBCAT       37 non-null     object
#  3   MAINTENANCE  37 non-null     object
# dtypes: object(4)
# memory usage: 1.3+ KB

# %%
# Fix customer ID format
ERP_loc['CID'] = ERP_loc['CID'].astype(str)
ERP_loc['CID'] = ERP_loc['CID'].str.split('-')
ERP_loc['CID'] = ERP_loc['CID'].apply(lambda x: ''.join(x))
ERP_loc.head()
# Out:
#           CID      CNTRY
# 0  AW00011000  Australia
# 1  AW00011001  Australia
# 2  AW00011002  Australia
# 3  AW00011003  Australia
# 4  AW00011004  Australia

# %%
# Merge Customer and Location DataFrames
ERP_cust_loc = ERP_cust.merge(ERP_loc, how='left', left_on='CID', right_on='CID')
ERP_cust_loc
# Out:
#                  CID      BDATE     GEN           CNTRY
# 0      NASAW00011000 1971-10-06    Male             NaN
# 1      NASAW00011001 1976-05-10    Male             NaN
# 2      NASAW00011002 1971-02-09    Male             NaN
# 3      NASAW00011003 1973-08-14  Female             NaN
# 4      NASAW00011004 1979-08-05  Female             NaN
# ...              ...        ...     ...             ...
# 18479     AW00029479 1969-06-30    None          France
# 18480     AW00029480 1977-05-06    None  United Kingdom
# 18481     AW00029481 1965-07-04    None         Germany
# 18482     AW00029482 1964-09-01    None          France
# 18483     AW00029483 1965-06-06    None          France
#
# [18484 rows x 4 columns]

# %%
ERP_cust_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CID     18484 non-null  object
#  1   BDATE   18479 non-null  datetime64[ns]
#  2   GEN     17012 non-null  object
#  3   CNTRY   7442 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 577.8+ KB

# %% [markdown]
# ### **Merge CRM and ERP**

# %%
# Create keyword dictionary
keyword_subcat_map = {
    'Mountain': 'Mountain Bikes',
    'Road': 'Road Bikes',
    'Touring': 'Touring Bikes',
    'Tire': 'Tires and Tubes',
    'Tube': 'Tires and Tubes',
    'Bottle': 'Bottles and Cages',
    'Cage': 'Bottles and Cages',
    'Helmet': 'Helmets',
    'Gloves': 'Gloves',
    'Jersey': 'Jerseys',
    'Socks': 'Socks',
    'Cap': 'Caps',
    'Vest': 'Vests',
    'Shorts': 'Shorts',
    'Bib-Shorts': 'Bib-Shorts',
    'Hydration Pack': 'Hydration Packs',
    'Bike Wash': 'Cleaners',
    'Patch': 'Cleaners',
    'Fender': 'Fenders',
    'Stand': 'Bike Stands',
    'Rack': 'Bike Racks',
}

# Function to assign subcategory based on the keyword found
def assign_subcat(prd_name, keyword_map):
    for keyword, subcat in keyword_map.items():
        if keyword.lower() in prd_name.lower():
            return subcat
    return 'Unknown'

# Map to subcategory
CRM_sales_cust_prod['subcat'] = CRM_sales_cust_prod['prd_nm'].apply(lambda x: assign_subcat(x, keyword_subcat_map))
CRM_sales_cust_prod
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05
# 1         SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05
# 2         SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05
# 3         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# 4         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# ...           ...         ...          ...          ...         ...
# 89828     SO75123     FE-6654        18759   2014-01-28  2014-02-04
# 89829     SO75123     ST-1401        18759   2014-01-28  2014-02-04
# 89830     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89831     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89832     SO75123     CA-1098        18759   2014-01-28  2014-02-04
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price  cst_id     cst_key  \
# 0     2011-01-10     3578.0             1     3578.0   21768  AW00021768
# 1     2011-01-10     3400.0             1     3400.0   28389  AW00028389
# 2     2011-01-10     3400.0             1     3400.0   25863  AW00025863
# 3     2011-01-10      699.0             1      699.0   14501  AW00014501
# 4     2011-01-10      699.0             1      699.0   14501  AW00014501
# ...          ...        ...           ...        ...     ...         ...
# 89828 2014-02-09       22.0             1       22.0   18759  AW00018759
# 89829 2014-02-09      159.0             1      159.0   18759  AW00018759
# 89830 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89831 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89832 2014-02-09        9.0             1        9.0   18759  AW00018759
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date  \
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S        0      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M        0      2025-10-12
# 4             Ruben       Prasad                  M        0      2025-10-12
# ...             ...          ...                ...      ...             ...
# 89828         Devin     Phillips                  S        M      2026-01-04
# 89829         Devin     Phillips                  S        M      2026-01-04
# 89830         Devin     Phillips                  S        M      2026-01-04
# 89831         Devin     Phillips                  S        M      2026-01-04
# 89832         Devin     Phillips                  S        M      2026-01-04
#
#        prd_id     prd_key                   prd_nm  prd_cost prd_line  \
# 0         310  BK-R93R-62         Road-150 Red- 62    2171.0       R
# 1         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 2         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 3         336  BK-R50B-62       Road-650 Black- 62     413.0       R
# 4         337  BK-R50B-62       Road-650 Black- 62     487.0       R
# ...       ...         ...                      ...       ...      ...
# 89828     485     FE-6654    Fender Set - Mountain       8.0       M
# 89829     486     ST-1401   All-Purpose Bike Stand      59.0       M
# 89830     223     CA-1098             AWC Logo Cap       6.0       S
# 89831     224     CA-1098             AWC Logo Cap       5.0       S
# 89832     225     CA-1098             AWC Logo Cap       7.0       S
#
#       prd_start_dt prd_end_dt          subcat
# 0       2011-07-01 2007-12-28      Road Bikes
# 1       2011-07-01 2007-12-28  Mountain Bikes
# 2       2011-07-01 2007-12-28  Mountain Bikes
# 3       2011-07-01 2007-12-28      Road Bikes
# 4       2012-07-01 2008-12-27      Road Bikes
# ...            ...        ...             ...
# 89828   2013-07-01 1970-01-01  Mountain Bikes
# 89829   2013-07-01 1970-01-01     Bike Stands
# 89830   2011-07-01 2007-12-28            Caps
# 89831   2012-07-01 2008-12-27            Caps
# 89832   2013-07-01 1970-01-01            Caps
#
# [89833 rows x 24 columns]

# %%
# Merge CRM final and ERP Product DataFrames
CRM_ERP_prod = CRM_sales_cust_prod.merge(ERP_px, how='left', left_on='subcat', right_on='SUBCAT')
CRM_ERP_prod
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05
# 1         SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05
# 2         SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05
# 3         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# 4         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# ...           ...         ...          ...          ...         ...
# 89828     SO75123     FE-6654        18759   2014-01-28  2014-02-04
# 89829     SO75123     ST-1401        18759   2014-01-28  2014-02-04
# 89830     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89831     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89832     SO75123     CA-1098        18759   2014-01-28  2014-02-04
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price  cst_id     cst_key  \
# 0     2011-01-10     3578.0             1     3578.0   21768  AW00021768
# 1     2011-01-10     3400.0             1     3400.0   28389  AW00028389
# 2     2011-01-10     3400.0             1     3400.0   25863  AW00025863
# 3     2011-01-10      699.0             1      699.0   14501  AW00014501
# 4     2011-01-10      699.0             1      699.0   14501  AW00014501
# ...          ...        ...           ...        ...     ...         ...
# 89828 2014-02-09       22.0             1       22.0   18759  AW00018759
# 89829 2014-02-09      159.0             1      159.0   18759  AW00018759
# 89830 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89831 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89832 2014-02-09        9.0             1        9.0   18759  AW00018759
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date  \
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S        0      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M        0      2025-10-12
# 4             Ruben       Prasad                  M        0      2025-10-12
# ...             ...          ...                ...      ...             ...
# 89828         Devin     Phillips                  S        M      2026-01-04
# 89829         Devin     Phillips                  S        M      2026-01-04
# 89830         Devin     Phillips                  S        M      2026-01-04
# 89831         Devin     Phillips                  S        M      2026-01-04
# 89832         Devin     Phillips                  S        M      2026-01-04
#
#        prd_id     prd_key                   prd_nm  prd_cost prd_line  \
# 0         310  BK-R93R-62         Road-150 Red- 62    2171.0       R
# 1         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 2         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 3         336  BK-R50B-62       Road-650 Black- 62     413.0       R
# 4         337  BK-R50B-62       Road-650 Black- 62     487.0       R
# ...       ...         ...                      ...       ...      ...
# 89828     485     FE-6654    Fender Set - Mountain       8.0       M
# 89829     486     ST-1401   All-Purpose Bike Stand      59.0       M
# 89830     223     CA-1098             AWC Logo Cap       6.0       S
# 89831     224     CA-1098             AWC Logo Cap       5.0       S
# 89832     225     CA-1098             AWC Logo Cap       7.0       S
#
#       prd_start_dt prd_end_dt          subcat     ID          CAT  \
# 0       2011-07-01 2007-12-28      Road Bikes  BI_RB        Bikes
# 1       2011-07-01 2007-12-28  Mountain Bikes  BI_MB        Bikes
# 2       2011-07-01 2007-12-28  Mountain Bikes  BI_MB        Bikes
# 3       2011-07-01 2007-12-28      Road Bikes  BI_RB        Bikes
# 4       2012-07-01 2008-12-27      Road Bikes  BI_RB        Bikes
# ...            ...        ...             ...    ...          ...
# 89828   2013-07-01 1970-01-01  Mountain Bikes  BI_MB        Bikes
# 89829   2013-07-01 1970-01-01     Bike Stands  AC_BS  Accessories
# 89830   2011-07-01 2007-12-28            Caps  CL_CA     Clothing
# 89831   2012-07-01 2008-12-27            Caps  CL_CA     Clothing
# 89832   2013-07-01 1970-01-01            Caps  CL_CA     Clothing
#
#                SUBCAT MAINTENANCE
# 0          Road Bikes         Yes
# 1      Mountain Bikes         Yes
# 2      Mountain Bikes         Yes
# 3          Road Bikes         Yes
# 4          Road Bikes         Yes
# ...               ...         ...
# 89828  Mountain Bikes         Yes
# 89829     Bike Stands          No
# 89830            Caps          No
# 89831            Caps          No
# 89832            Caps          No
#
# [89833 rows x 28 columns]

# %%
# Merge CRM and ERP DataFrames
CRM_ERP = CRM_ERP_prod.merge(ERP_cust_loc, how='left', left_on='cst_key', right_on='CID')
CRM_ERP
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id sls_order_dt sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768   2010-12-29  2011-01-05
# 1         SO43698  BK-M82S-44        28389   2010-12-29  2011-01-05
# 2         SO43699  BK-M82S-44        25863   2010-12-29  2011-01-05
# 3         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# 4         SO43700  BK-R50B-62        14501   2010-12-29  2011-01-05
# ...           ...         ...          ...          ...         ...
# 89828     SO75123     FE-6654        18759   2014-01-28  2014-02-04
# 89829     SO75123     ST-1401        18759   2014-01-28  2014-02-04
# 89830     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89831     SO75123     CA-1098        18759   2014-01-28  2014-02-04
# 89832     SO75123     CA-1098        18759   2014-01-28  2014-02-04
#
#       sls_due_dt  sls_sales  sls_quantity  sls_price  cst_id     cst_key  \
# 0     2011-01-10     3578.0             1     3578.0   21768  AW00021768
# 1     2011-01-10     3400.0             1     3400.0   28389  AW00028389
# 2     2011-01-10     3400.0             1     3400.0   25863  AW00025863
# 3     2011-01-10      699.0             1      699.0   14501  AW00014501
# 4     2011-01-10      699.0             1      699.0   14501  AW00014501
# ...          ...        ...           ...        ...     ...         ...
# 89828 2014-02-09       22.0             1       22.0   18759  AW00018759
# 89829 2014-02-09      159.0             1      159.0   18759  AW00018759
# 89830 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89831 2014-02-09        9.0             1        9.0   18759  AW00018759
# 89832 2014-02-09        9.0             1        9.0   18759  AW00018759
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date  \
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S        0      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M        0      2025-10-12
# 4             Ruben       Prasad                  M        0      2025-10-12
# ...             ...          ...                ...      ...             ...
# 89828         Devin     Phillips                  S        M      2026-01-04
# 89829         Devin     Phillips                  S        M      2026-01-04
# 89830         Devin     Phillips                  S        M      2026-01-04
# 89831         Devin     Phillips                  S        M      2026-01-04
# 89832         Devin     Phillips                  S        M      2026-01-04
#
#        prd_id     prd_key                   prd_nm  prd_cost prd_line  \
# 0         310  BK-R93R-62         Road-150 Red- 62    2171.0       R
# 1         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 2         346  BK-M82S-44  Mountain-100 Silver- 44    1912.0       M
# 3         336  BK-R50B-62       Road-650 Black- 62     413.0       R
# 4         337  BK-R50B-62       Road-650 Black- 62     487.0       R
# ...       ...         ...                      ...       ...      ...
# 89828     485     FE-6654    Fender Set - Mountain       8.0       M
# 89829     486     ST-1401   All-Purpose Bike Stand      59.0       M
# 89830     223     CA-1098             AWC Logo Cap       6.0       S
# 89831     224     CA-1098             AWC Logo Cap       5.0       S
# 89832     225     CA-1098             AWC Logo Cap       7.0       S
#
#       prd_start_dt prd_end_dt          subcat     ID          CAT  \
# 0       2011-07-01 2007-12-28      Road Bikes  BI_RB        Bikes
# 1       2011-07-01 2007-12-28  Mountain Bikes  BI_MB        Bikes
# 2       2011-07-01 2007-12-28  Mountain Bikes  BI_MB        Bikes
# 3       2011-07-01 2007-12-28      Road Bikes  BI_RB        Bikes
# 4       2012-07-01 2008-12-27      Road Bikes  BI_RB        Bikes
# ...            ...        ...             ...    ...          ...
# 89828   2013-07-01 1970-01-01  Mountain Bikes  BI_MB        Bikes
# 89829   2013-07-01 1970-01-01     Bike Stands  AC_BS  Accessories
# 89830   2011-07-01 2007-12-28            Caps  CL_CA     Clothing
# 89831   2012-07-01 2008-12-27            Caps  CL_CA     Clothing
# 89832   2013-07-01 1970-01-01            Caps  CL_CA     Clothing
#
#                SUBCAT MAINTENANCE         CID      BDATE     GEN  \
# 0          Road Bikes         Yes         NaN        NaT     NaN
# 1      Mountain Bikes         Yes  AW00028389 1970-06-17  Female
# 2      Mountain Bikes         Yes  AW00025863 1952-06-01  Female
# 3          Road Bikes         Yes         NaN        NaT     NaN
# 4          Road Bikes         Yes         NaN        NaT     NaN
# ...               ...         ...         ...        ...     ...
# 89828  Mountain Bikes         Yes         NaN        NaT     NaN
# 89829     Bike Stands          No         NaN        NaT     NaN
# 89830            Caps          No         NaN        NaT     NaN
# 89831            Caps          No         NaN        NaT     NaN
# 89832            Caps          No         NaN        NaT     NaN
#
#                CNTRY
# 0                NaN
# 1             France
# 2      United States
# 3                NaN
# 4                NaN
# ...              ...
# 89828            NaN
# 89829            NaN
# 89830            NaN
# 89831            NaN
# 89832            NaN
#
# [89833 rows x 32 columns]

# %%
# Remove redundant columns
CRM_ERP = CRM_ERP.drop(columns=['sls_prd_key', 'sls_cust_id', 'CID', 'SUBCAT', 'cst_gndr'])

# Remove zero values
CRM_ERP = CRM_ERP.replace(0, np.nan)
CRM_ERP_clean = CRM_ERP.dropna()
CRM_ERP_clean
# Out:
#       sls_ord_num sls_order_dt sls_ship_dt sls_due_dt  sls_sales  \
# 1         SO43698   2010-12-29  2011-01-05 2011-01-10     3400.0
# 2         SO43699   2010-12-29  2011-01-05 2011-01-10     3400.0
# 6         SO43702   2010-12-30  2011-01-06 2011-01-11     3578.0
# 10        SO43706   2010-12-31  2011-01-07 2011-01-12     3578.0
# 11        SO43707   2010-12-31  2011-01-07 2011-01-12     3578.0
# ...           ...          ...         ...        ...        ...
# 89741     SO75098   2014-01-28  2014-02-04 2014-02-09        2.0
# 89799     SO75114   2014-01-28  2014-02-04 2014-02-09       21.0
# 89800     SO75115   2014-01-28  2014-02-04 2014-02-09       21.0
# 89801     SO75115   2014-01-28  2014-02-04 2014-02-09        4.0
# 89802     SO75115   2014-01-28  2014-02-04 2014-02-09       55.0
#
#        sls_quantity  sls_price  cst_id     cst_key cst_firstname cst_lastname  \
# 1                 1     3400.0   28389  AW00028389       Rachael     Martinez
# 2                 1     3400.0   25863  AW00025863        Sydney       Wright
# 6                 1     3578.0   27645  AW00027645         Colin        Anand
# 10                1     3578.0   27621  AW00027621        Edward        Brown
# 11                1     3578.0   27616  AW00027616          Emma        Brown
# ...             ...        ...     ...         ...           ...          ...
# 89741             1        2.0   23381  AW00023381        Bianca           Hu
# 89799             1       21.0   24704  AW00024704         Allen      Schmidt
# 89800             1       21.0   26832  AW00026832          Kate          Xie
# 89801             1        4.0   26832  AW00026832          Kate          Xie
# 89802             1       55.0   26832  AW00026832          Kate          Xie
#
#       cst_marital_status cst_create_date  prd_id     prd_key  \
# 1                      S      2026-01-25     346  BK-M82S-44
# 2                      S      2026-01-14     346  BK-M82S-44
# 6                      M      2026-01-25     311  BK-R93R-44
# 10                     S      2026-01-25     312  BK-R93R-48
# 11                     S      2026-01-21     312  BK-R93R-48
# ...                  ...             ...     ...         ...
# 89741                  M      2026-01-05     480     PK-7098
# 89799                  M      2026-01-05     538     TI-R092
# 89800                  M      2026-01-14     538     TI-R092
# 89801                  M      2026-01-14     529     TT-R982
# 89802                  M      2026-01-14     487  HY-1023-70
#
#                         prd_nm  prd_cost prd_line prd_start_dt prd_end_dt  \
# 1      Mountain-100 Silver- 44    1912.0       M    2011-07-01 2007-12-28
# 2      Mountain-100 Silver- 44    1912.0       M    2011-07-01 2007-12-28
# 6             Road-150 Red- 44    2171.0       R    2011-07-01 2007-12-28
# 10            Road-150 Red- 48    2171.0       R    2011-07-01 2007-12-28
# 11            Road-150 Red- 48    2171.0       R    2011-07-01 2007-12-28
# ...                        ...       ...      ...          ...        ...
# 89741      Patch Kit/8 Patches       1.0       S    2013-07-01 1970-01-01
# 89799             LL Road Tire       8.0       R    2013-07-01 1970-01-01
# 89800             LL Road Tire       8.0       R    2013-07-01 1970-01-01
# 89801           Road Tire Tube       1.0       R    2013-07-01 1970-01-01
# 89802  Hydration Pack - 70 oz.      21.0       S    2013-07-01 1970-01-01
#
#                 subcat     ID          CAT MAINTENANCE      BDATE     GEN  \
# 1       Mountain Bikes  BI_MB        Bikes         Yes 1970-06-17  Female
# 2       Mountain Bikes  BI_MB        Bikes         Yes 1952-06-01  Female
# 6           Road Bikes  BI_RB        Bikes         Yes 1972-08-14    Male
# 10          Road Bikes  BI_RB        Bikes         Yes 1975-01-23    Male
# 11          Road Bikes  BI_RB        Bikes         Yes 1971-06-10  Female
# ...                ...    ...          ...         ...        ...     ...
# 89741         Cleaners  AC_CL  Accessories         Yes 1967-01-08  Female
# 89799       Road Bikes  BI_RB        Bikes         Yes 1983-03-10    Male
# 89800       Road Bikes  BI_RB        Bikes         Yes 1977-01-30  Female
# 89801       Road Bikes  BI_RB        Bikes         Yes 1977-01-30  Female
# 89802  Hydration Packs  AC_HP  Accessories          No 1977-01-30  Female
#
#                CNTRY
# 1             France
# 2      United States
# 6      United States
# 10     United States
# 11     United States
# ...              ...
# 89741  United States
# 89799        Germany
# 89800        Germany
# 89801        Germany
# 89802        Germany
#
# [27166 rows x 27 columns]

# %%
# Fix column name format
CRM_ERP_clean = CRM_ERP_clean.rename(columns={
    'sls_ord_num': 'OrderNumber',
    'sls_order_dt': 'OrderDate',
    'sls_ship_dt': 'ShipDate',
    'sls_due_dt': 'DueDate',
    'sls_sales': 'SalesAmount',
    'sls_quantity': 'Quantity',
    'sls_price': 'UnitPrice',
    'cst_id': 'CustomerID',
    'cst_key': 'CustomerKey',
    'cst_firstname': 'FirstName',
    'cst_lastname': 'LastName',
    'cst_marital_status': 'MaritalStatus',
    'cst_create_date': 'CustomerCreateDate',
    'prd_id': 'ProductID',
    'prd_key': 'ProductKey',
    'prd_nm': 'ProductName',
    'prd_cost': 'ProductCost',
    'prd_line': 'ProductLine',
    'prd_start_dt': 'ProductStartDate',
    'prd_end_dt': 'ProductEndDate',
    'subcat': 'SubCategory',
    'ID': 'SubCategoryID',
    'CAT': 'Category',
    'MAINTENANCE': 'MaintenancePlan',
    'BDATE': 'BirthDate',
    'GEN': 'Gender',
    'CNTRY': 'Country'
})

# Reorder columns
desired_order = [
    'OrderNumber', 'OrderDate', 'ShipDate', 'DueDate', 'SalesAmount', 'Quantity', 'UnitPrice',
    'CustomerID', 'CustomerKey', 'FirstName', 'LastName', 'MaritalStatus', 'BirthDate', 'Gender', 'Country', 'CustomerCreateDate',
    'ProductID', 'ProductKey', 'ProductName', 'ProductCost', 'ProductLine', 'ProductStartDate', 'ProductEndDate',
    'SubCategory', 'SubCategoryID', 'Category', 'MaintenancePlan'
]
CRM_ERP_clean = CRM_ERP_clean[desired_order]

# Reset index
CRM_ERP_final = CRM_ERP_clean.reset_index(drop=True)
CRM_ERP_final
# Out:
#       OrderNumber  OrderDate   ShipDate    DueDate  SalesAmount  Quantity  \
# 0         SO43698 2010-12-29 2011-01-05 2011-01-10       3400.0         1
# 1         SO43699 2010-12-29 2011-01-05 2011-01-10       3400.0         1
# 2         SO43702 2010-12-30 2011-01-06 2011-01-11       3578.0         1
# 3         SO43706 2010-12-31 2011-01-07 2011-01-12       3578.0         1
# 4         SO43707 2010-12-31 2011-01-07 2011-01-12       3578.0         1
# ...           ...        ...        ...        ...          ...       ...
# 27161     SO75098 2014-01-28 2014-02-04 2014-02-09          2.0         1
# 27162     SO75114 2014-01-28 2014-02-04 2014-02-09         21.0         1
# 27163     SO75115 2014-01-28 2014-02-04 2014-02-09         21.0         1
# 27164     SO75115 2014-01-28 2014-02-04 2014-02-09          4.0         1
# 27165     SO75115 2014-01-28 2014-02-04 2014-02-09         55.0         1
#
#        UnitPrice  CustomerID CustomerKey FirstName  LastName MaritalStatus  \
# 0         3400.0       28389  AW00028389   Rachael  Martinez             S
# 1         3400.0       25863  AW00025863    Sydney    Wright             S
# 2         3578.0       27645  AW00027645     Colin     Anand             M
# 3         3578.0       27621  AW00027621    Edward     Brown             S
# 4         3578.0       27616  AW00027616      Emma     Brown             S
# ...          ...         ...         ...       ...       ...           ...
# 27161        2.0       23381  AW00023381    Bianca        Hu             M
# 27162       21.0       24704  AW00024704     Allen   Schmidt             M
# 27163       21.0       26832  AW00026832      Kate       Xie             M
# 27164        4.0       26832  AW00026832      Kate       Xie             M
# 27165       55.0       26832  AW00026832      Kate       Xie             M
#
#        BirthDate  Gender        Country CustomerCreateDate  ProductID  \
# 0     1970-06-17  Female         France         2026-01-25        346
# 1     1952-06-01  Female  United States         2026-01-14        346
# 2     1972-08-14    Male  United States         2026-01-25        311
# 3     1975-01-23    Male  United States         2026-01-25        312
# 4     1971-06-10  Female  United States         2026-01-21        312
# ...          ...     ...            ...                ...        ...
# 27161 1967-01-08  Female  United States         2026-01-05        480
# 27162 1983-03-10    Male        Germany         2026-01-05        538
# 27163 1977-01-30  Female        Germany         2026-01-14        538
# 27164 1977-01-30  Female        Germany         2026-01-14        529
# 27165 1977-01-30  Female        Germany         2026-01-14        487
#
#        ProductKey              ProductName  ProductCost ProductLine  \
# 0      BK-M82S-44  Mountain-100 Silver- 44       1912.0          M
# 1      BK-M82S-44  Mountain-100 Silver- 44       1912.0          M
# 2      BK-R93R-44         Road-150 Red- 44       2171.0          R
# 3      BK-R93R-48         Road-150 Red- 48       2171.0          R
# 4      BK-R93R-48         Road-150 Red- 48       2171.0          R
# ...           ...                      ...          ...         ...
# 27161     PK-7098      Patch Kit/8 Patches          1.0          S
# 27162     TI-R092             LL Road Tire          8.0          R
# 27163     TI-R092             LL Road Tire          8.0          R
# 27164     TT-R982           Road Tire Tube          1.0          R
# 27165  HY-1023-70  Hydration Pack - 70 oz.         21.0          S
#
#       ProductStartDate ProductEndDate      SubCategory SubCategoryID  \
# 0           2011-07-01     2007-12-28   Mountain Bikes         BI_MB
# 1           2011-07-01     2007-12-28   Mountain Bikes         BI_MB
# 2           2011-07-01     2007-12-28       Road Bikes         BI_RB
# 3           2011-07-01     2007-12-28       Road Bikes         BI_RB
# 4           2011-07-01     2007-12-28       Road Bikes         BI_RB
# ...                ...            ...              ...           ...
# 27161       2013-07-01     1970-01-01         Cleaners         AC_CL
# 27162       2013-07-01     1970-01-01       Road Bikes         BI_RB
# 27163       2013-07-01     1970-01-01       Road Bikes         BI_RB
# 27164       2013-07-01     1970-01-01       Road Bikes         BI_RB
# 27165       2013-07-01     1970-01-01  Hydration Packs         AC_HP
#
#           Category MaintenancePlan
# 0            Bikes             Yes
# 1            Bikes             Yes
# 2            Bikes             Yes
# 3            Bikes             Yes
# 4            Bikes             Yes
# ...            ...             ...
# 27161  Accessories             Yes
# 27162        Bikes             Yes
# 27163        Bikes             Yes
# 27164        Bikes             Yes
# 27165  Accessories              No
#
# [27166 rows x 27 columns]

# %%
CRM_ERP_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27166 entries, 0 to 27165
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderNumber         27166 non-null  object
#  1   OrderDate           27166 non-null  datetime64[ns]
#  2   ShipDate            27166 non-null  datetime64[ns]
#  3   DueDate             27166 non-null  datetime64[ns]
#  4   SalesAmount         27166 non-null  float64
#  5   Quantity            27166 non-null  int64
#  6   UnitPrice           27166 non-null  float64
#  7   CustomerID          27166 non-null  int64
#  8   CustomerKey         27166 non-null  object
#  9   FirstName           27166 non-null  object
#  10  LastName            27166 non-null  object
#  11  MaritalStatus       27166 non-null  object
#  12  BirthDate           27166 non-null  datetime64[ns]
#  13  Gender              27166 non-null  object
#  14  Country             27166 non-null  object
#  15  CustomerCreateDate  27166 non-null  datetime64[ns]
#  16  ProductID           27166 non-null  int64
#  17  ProductKey          27166 non-null  object
#  18  ProductName         27166 non-null  object
#  19  ProductCost         27166 non-null  float64
#  20  ProductLine         27166 non-null  object
#  21  ProductStartDate    27166 non-null  datetime64[ns]
#  22  ProductEndDate      27166 non-null  datetime64[ns]
#  23  SubCategory         27166 non-null  object
#  24  SubCategoryID       27166 non-null  object
#  25  Category            27166 non-null  object
#  26  MaintenancePlan     27166 non-null  object
# dtypes: datetime64[ns](7), float64(3), int64(3), object(14)
# memory usage: 5.6+ MB

# %% [markdown]
# ## **Data Loading**
#
# Save cleaned data to Render (PostgreSQL) database with DuckDB extension.

# %%
# Connect to Data Warehouse
DataWarehouse_URL = os.getenv("DATA_WAREHOUSE_URL")
engine_dw = sqlalchemy.create_engine(DataWarehouse_URL, client_encoding='utf8')
connection_dw = engine_dw.connect()

# %%
# Save DataFrame to database
CRM_ERP_final.to_sql("crm_erp", con=connection_dw, if_exists="replace", index=False)
# Out:
# 166

# %%
# Verify the data was saved correctly
query = "SELECT * FROM crm_erp LIMIT 5;"
check_df = pd.read_sql(query, con=connection_dw)
check_df
# Out:
#   OrderNumber  OrderDate   ShipDate    DueDate  SalesAmount  Quantity  \
# 0     SO43698 2010-12-29 2011-01-05 2011-01-10       3400.0         1
# 1     SO43699 2010-12-29 2011-01-05 2011-01-10       3400.0         1
# 2     SO43702 2010-12-30 2011-01-06 2011-01-11       3578.0         1
# 3     SO43706 2010-12-31 2011-01-07 2011-01-12       3578.0         1
# 4     SO43707 2010-12-31 2011-01-07 2011-01-12       3578.0         1
#
#    UnitPrice  CustomerID CustomerKey FirstName  LastName MaritalStatus  \
# 0     3400.0       28389  AW00028389   Rachael  Martinez             S
# 1     3400.0       25863  AW00025863    Sydney    Wright             S
# 2     3578.0       27645  AW00027645     Colin     Anand             M
# 3     3578.0       27621  AW00027621    Edward     Brown             S
# 4     3578.0       27616  AW00027616      Emma     Brown             S
#
#    BirthDate  Gender        Country CustomerCreateDate  ProductID  ProductKey  \
# 0 1970-06-17  Female         France         2026-01-25        346  BK-M82S-44
# 1 1952-06-01  Female  United States         2026-01-14        346  BK-M82S-44
# 2 1972-08-14    Male  United States         2026-01-25        311  BK-R93R-44
# 3 1975-01-23    Male  United States         2026-01-25        312  BK-R93R-48
# 4 1971-06-10  Female  United States         2026-01-21        312  BK-R93R-48
#
#                ProductName  ProductCost ProductLine ProductStartDate  \
# 0  Mountain-100 Silver- 44       1912.0          M        2011-07-01
# 1  Mountain-100 Silver- 44       1912.0          M        2011-07-01
# 2         Road-150 Red- 44       2171.0          R        2011-07-01
# 3         Road-150 Red- 48       2171.0          R        2011-07-01
# 4         Road-150 Red- 48       2171.0          R        2011-07-01
#
#   ProductEndDate     SubCategory SubCategoryID Category MaintenancePlan
# 0     2007-12-28  Mountain Bikes         BI_MB    Bikes             Yes
# 1     2007-12-28  Mountain Bikes         BI_MB    Bikes             Yes
# 2     2007-12-28      Road Bikes         BI_RB    Bikes             Yes
# 3     2007-12-28      Road Bikes         BI_RB    Bikes             Yes
# 4     2007-12-28      Road Bikes         BI_RB    Bikes             Yes

# %%
# Verify the extensions
query_ext = "SELECT * FROM pg_extension;"
pd.read_sql(query_ext, con=connection_dw)
# Out:
#      oid    extname  extowner  extnamespace  extrelocatable extversion  \
# 0  13564    plpgsql        10            11           False        1.0
# 1  16399  pg_duckdb     16385          2200           False      0.2.0
#
#   extconfig extcondition
# 0      None         None
# 1      None         None

# %%
# Close connections and dispose engines
connection_dw.close()
engine_dw.dispose()
